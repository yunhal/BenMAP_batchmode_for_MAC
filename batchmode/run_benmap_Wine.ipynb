# %% [markdown]
# ## Run BenMAP batch mode using Wine
#
# Author : Yunha Lee
#
# Date: March 13, 2025

# %%
import os
import subprocess


def base_AQG_process_template(template_path, output_path, base_run, AQG_wine_dir, inmap_wine_dir, grid_level):
    """Reads a template file, replaces placeholders with actual paths, and saves the modified file."""
    with open(template_path, 'r') as f:
        content = f.read()
    
    # Replace placeholders
    content = content.replace('{AQG_wine_dir}', AQG_wine_dir)
    content = content.replace('{inmap_wine_dir}', inmap_wine_dir)
    content = content.replace('{base_run}', base_run)
    content = content.replace('{grid_level}', grid_level)

    print("AQG debug", output_path)
    # Write the modified content to a new file
    with open(output_path, 'w') as f:
        f.write(content)

def AQG_process_template(template_path, output_path, control_run, AQG_wine_dir, inmap_wine_dir, grid_level):
    """Reads a template file, replaces placeholders with actual paths, and saves the modified file."""
    with open(template_path, 'r') as f:
        content = f.read()
    
    # Replace placeholders
    content = content.replace('{AQG_wine_dir}', AQG_wine_dir)
    content = content.replace('{inmap_wine_dir}', inmap_wine_dir)
    content = content.replace('{control_run}', control_run)
    content = content.replace('{grid_level}', grid_level)

    print("AQG debug", output_path)
    # Write the modified content to a new file
    with open(output_path, 'w') as f:
        f.write(content)


def CFG_process_template(template_path, output_path, control_run, base_run, CFG_wine_dir, CFGR_wine_dir, AQG_wine_dir):
    """Reads a template file, replaces placeholders with actual paths, and saves the modified file."""
    with open(template_path, 'r') as f:
        content = f.read()
    
    # Replace placeholders
    content = content.replace('{CFG_wine_dir}', CFG_wine_dir)
    content = content.replace('{CFGR_wine_dir}', CFGR_wine_dir)
    content = content.replace('{AQG_wine_dir}', AQG_wine_dir)
    content = content.replace('{control_run}', control_run)
    content = content.replace('{base_run}', base_run)

    # Write the modified content to a new file
    with open(output_path, 'w') as f:
        f.write(content)

def APV_process_template(template_path, output_path, control_run, APV_wine_dir, APVR_wine_dir, CFGR_wine_dir, grid_level):
    """Reads a template file, replaces placeholders with actual paths, and saves the modified file."""
    with open(template_path, 'r') as f:
        content = f.read()
    
    # Replace placeholders
    content = content.replace('{APV_wine_dir}', APV_wine_dir)
    content = content.replace('{APVR_wine_dir}', APVR_wine_dir)
    content = content.replace('{CFGR_wine_dir}', CFGR_wine_dir)
    content = content.replace('{control_run}', control_run)
    content = content.replace('{grid_level}', grid_level)

    # Write the modified content to a new file
    with open(output_path, 'w') as f:
        f.write(content)

# Function to convert Unix paths to Wine-compatible Windows paths
def convert_to_wine_path(unix_path):
    windows_path = unix_path #s.replace('/', '\\')  # Convert to Windows-style backslashes
    return "Z:" + windows_path  # Prepend Z: for Wine


# Control run names
control_runs = ['LA_CCS', 'LA_CCS_noNH3'] #['CO_Suncor_CCS_wo_NH3_VOC', 'NEI_no_Landfill_2001411', 'CO_CCS', 'CO_CCS_wo_NH3_VOC', 'CO_Cherokee_CCS_wo_NH3_VOC']

# grid level
grid_dict =  {'County':'county'} # {'US Census Tracts' : 'tracts' } # 

# Key directories
Benmap_dir = '/Users/yunhalee/Documents/LOCAETA/RCM/BenMAP/'
AQG_dir = Benmap_dir + 'batchmode/AQG/'
CFG_dir = Benmap_dir +'batchmode/CFG/'
APV_dir = Benmap_dir +'batchmode/APV/'

# wine style directories
CFGR_wine_dir = 'Z:'+ Benmap_dir + 'batchmode/CFGR/'
APVR_wine_dir = 'Z:'+ Benmap_dir + 'batchmode/APVR/'

# Name of template ctlx file
ctlx_template = f'control_template_inmap_2020_pm25_wine.ctlx'
base_ctlx_template = f'base_template_inmap_2020_pm25_wine.ctlx'

# Wine executable path
benmap_exe = "C:\\Program Files (x86)\\BenMAP-CE\\BenMAP.exe"

for grid_level, grid_file_name in grid_dict.items():

    print (grid_level, grid_file_name)

    inmap_wine_dir = 'Z:' + Benmap_dir +'inmap_output/' + f'{grid_file_name}_case/' # directory of air quality input csv files

    # Base run placeholder in template
    base_run = f'base_{grid_file_name}_inmap_2020_pm25' 

    # # Process and run AQG template
    # AQG_wine_dir = convert_to_wine_path(AQG_dir)
    # aqg_template = os.path.join(AQG_dir, base_ctlx_template)
    # aqg_output = os.path.join(AQG_dir, f'{base_run}_wine.ctlx')
    # base_AQG_process_template(aqg_template, aqg_output, base_run, AQG_wine_dir, inmap_wine_dir, grid_level)
    
    # subprocess.run(["wine", benmap_exe, convert_to_wine_path(aqg_output)], check=True)

    for run in control_runs:

        control_run = f'control_{run}_{grid_file_name}_inmap_2020_pm25'

        # Process and run AQG template
        AQG_wine_dir = convert_to_wine_path(AQG_dir)
        aqg_template = os.path.join(AQG_dir, ctlx_template)
        aqg_output = os.path.join(AQG_dir, f'{control_run}_wine.ctlx')
        # AQG_process_template(aqg_template, aqg_output, control_run, AQG_wine_dir, inmap_wine_dir, grid_level)

        # subprocess.run(["wine", benmap_exe, convert_to_wine_path(aqg_output)], check=True)

        # Process and run CFG template
        CFG_wine_dir = convert_to_wine_path(CFG_dir)
        cfg_template = os.path.join(CFG_dir, ctlx_template)
        cfg_output = os.path.join(CFG_dir, f'{control_run}_wine.ctlx')
        CFG_process_template(cfg_template, cfg_output, control_run, base_run, CFG_wine_dir, CFGR_wine_dir, AQG_wine_dir)

        subprocess.run(["wine", benmap_exe, convert_to_wine_path(cfg_output)], check=True)

        # Process and run APV template
        APV_wine_dir = convert_to_wine_path(APV_dir)
        apv_template = os.path.join(APV_dir, ctlx_template)
        apv_output = os.path.join(APV_dir, f'{control_run}_wine.ctlx')
        APV_process_template(apv_template, apv_output, control_run, APV_wine_dir, APVR_wine_dir, CFGR_wine_dir, grid_level)

        subprocess.run(["wine", benmap_exe, convert_to_wine_path(apv_output)], check=True)
# Out:
# County county
# 0098:fixme:hid:handle_IRP_MN_QUERY_ID Unhandled type 00000005
# 0098:fixme:hid:handle_IRP_MN_QUERY_ID Unhandled type 00000005
# 0098:fixme:hid:handle_IRP_MN_QUERY_ID Unhandled type 00000005
# 0098:fixme:hid:handle_IRP_MN_QUERY_ID Unhandled type 00000005
# 0024:fixme:thread:get_thread_times not implemented on this platform
# 0024:fixme:heap:GetNumaHighestNodeNumber semi-stub: 000000000041FB74
# 0024:fixme:ntdll:NtQuerySystemInformation info_class SYSTEM_PERFORMANCE_INFORMATION
# 0108:err:ole:CoGetContextToken apartment not initialised
# 0024:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 4 0000000000585128 0000000000419E90 000000000041A840 0000000000000000
# 0024:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 3 00000000005DD380 000000000041A230 000000000041ABE0 0000000000000000
# 0024:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 3 00000000005DD380 000000000041A230 000000000041ABE0 0000000000000000
# 0024:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 4 0000000000585128 0000000000419E90 000000000041A840 0000000000000000
# 0024:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 3 00000000005DD380 000000000041A230 000000000041ABE0 0000000000000000
# 0024:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 3 00000000005DD380 000000000041A230 000000000041ABE0 0000000000000000
# 0024:fixme:nls:get_dummy_preferred_ui_language (0x8 0x409 000000000041D0D0 0000000000000000 000000000041D0D4) returning a dummy value (current locale)
# 0024:fixme:nls:get_dummy_preferred_ui_language (0x8 0x409 000000000041D0D0 000000000061ADC0 000000000041D0D4) returning a dummy value (current locale)
# 0024:fixme:font:find_matching_face Untranslated charset 255
# 0024:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Apple Braille.ttf"
# 0024:fixme:font:find_matching_face Untranslated charset 255
# 0024:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\Baghdad.ttc"
# 0024:fixme:font:find_matching_face Untranslated charset 255
# 0024:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\Gujarati Sangam MN.ttc"
# 0024:fixme:font:find_matching_face Untranslated charset 255
# 0024:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\Gurmukhi Sangam MN.ttc"
# 0024:fixme:font:find_matching_face Untranslated charset 255
# 0024:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\HelveticaNeue.ttc"
# 0024:fixme:font:find_matching_face Untranslated charset 255
# 0024:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\Hoefler Text Ornaments.ttf"
# 0024:fixme:font:find_matching_face Untranslated charset 255
# 0024:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\ITFDevanagari.ttc"
# 0024:fixme:font:find_matching_face Untranslated charset 255
# 0024:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\ITFDevanagari.ttc"
# 0024:fixme:font:find_matching_face Untranslated charset 255
# 0024:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\Kailasa.ttc"
# 0024:fixme:font:find_matching_face Untranslated charset 255
# 0024:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\KohinoorGujarati.ttc"
# 0024:fixme:font:find_matching_face Untranslated charset 255
# 0024:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\KufiStandardGK.ttc"
# 0024:fixme:font:find_matching_face Untranslated charset 255
# 0024:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\Nadeem.ttc"
# 0024:fixme:font:find_matching_face Untranslated charset 255
# 0024:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\Skia.ttf"
# 0024:fixme:font:find_matching_face Untranslated charset 255
# 0024:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\ZapfDingbats.ttf"
# 0024:fixme:gdiplus:GdipGetFamilyName No support for handling of multiple languages!
# 0024:fixme:nls:LCMapStringEx unsupported lparam 5fb570
# 0024:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0024:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 000000000041E6B8 stub
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:virtual:NtFlushProcessWriteBuffers stub
# 0024:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 000000000041E358 stub
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 0000000000418258 stub
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 00000000004184B8 stub
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 0000000000418558 stub
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 4 0000000000691358 0000000000415220 0000000000415BD0 0000000000000000
# 0024:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 3 0000000000685470 00000000004155C0 0000000000415F70 0000000000000000
# 0024:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 3 0000000000685470 00000000004155C0 0000000000415F70 0000000000000000
# 0024:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 4 0000000000691358 0000000000415220 0000000000415BD0 0000000000000000
# 0024:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 3 0000000000685470 00000000004155C0 0000000000415F70 0000000000000000
# 0024:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 3 0000000000685470 00000000004155C0 0000000000415F70 0000000000000000
# 0024:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 00000000004186C8 stub
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:olepicture:OLEPictureImpl_QueryInterface () : asking for unsupported interface {c3fcc19e-a970-11d2-8b5a-00a0c9b7c9c4}
# 0024:fixme:olepicture:OLEPictureImpl_QueryInterface () : asking for unsupported interface {b196b283-bab4-101a-b69c-00aa00341d07}
# 0024:fixme:olepicture:OLEPictureImpl_QueryInterface () : asking for unsupported interface {af86e2e0-b12d-4c6a-9c5a-d7aa65101e90}
# 0024:fixme:olepicture:OLEPictureImpl_QueryInterface () : asking for unsupported interface {ecc8691b-c1db-4dc0-855e-65f6c551af49}
# 0024:fixme:olepicture:OLEPictureImpl_QueryInterface () : asking for unsupported interface {94ea2b94-e9cc-49e0-c0ff-ee64ca8f5b90}
# 0024:fixme:olepicture:OLEPictureImpl_QueryInterface () : asking for unsupported interface {00000003-0000-0000-c000-000000000046}
# 0024:fixme:olepicture:OLEPictureImpl_QueryInterface () : asking for unsupported interface {00000144-0000-0000-c000-000000000046}
# 0024:err:listview:LISTVIEW_WindowProc unknown msg 109d, wp 0, lp 0
# 0024:err:listview:LISTVIEW_SetImageList Unknown icon type=3
# 0024:err:listview:LISTVIEW_WindowProc unknown msg 109b, wp 0, lp 414a50
# 0024:err:listview:LISTVIEW_WindowProc unknown msg 109d, wp 0, lp 0
# 0024:err:listview:LISTVIEW_SetImageList Unknown icon type=3
# 0024:err:listview:LISTVIEW_WindowProc unknown msg 109b, wp 0, lp 414a50
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 0000000000413418 stub
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 012c:fixme:sync:SetWaitableTimerEx (00000000000003E8, 000000001DA5FED0, 500, 0000000000000000, 0000000000000000, 0000000000000000, 50) semi-stub
# 0128:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0128:fixme:combase:RoGetActivationFactory (L"Windows.Foundation.Diagnostics.AsyncCausalityTracer", {50850b26-267e-451b-a890-ab6a370245ee}, 000000001D95E740): semi-stub
# 0128:err:combase:RoGetActivationFactory Failed to find library for L"Windows.Foundation.Diagnostics.AsyncCausalityTracer"
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0148:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 014c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0138:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0168:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0144:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0158:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0154:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 017c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0154:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0164:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0168:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0024:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 00000000004133B8 stub
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0160:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0164:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 014c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0150:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0138:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0150:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0134:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0154:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0168:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0140:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0024:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 0000000000413418 stub
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0148:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0154:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0164:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0144:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0128:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 013c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0134:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0144:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0168:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0158:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0154:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0024:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 0000000000413418 stub
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0164:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0138:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 013c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0130:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 014c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 013c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0128:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0148:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0134:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0168:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0024:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 0000000000413418 stub
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0150:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 014c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 015c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 014c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 017c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0138:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0168:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0130:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0150:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0140:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0168:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0024:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 0000000000413418 stub
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 015c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0140:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0154:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0160:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0140:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0260:fixme:thread:get_thread_times not implemented on this platform
# 0260:fixme:seh:WerSetFlags (2) stub
# 0260:fixme:heap:RtlSetHeapInformation HEAP_INFORMATION_CLASS 1 not implemented!
# 027c:err:environ:init_peb starting L"C:\\windows\\Microsoft.NET\\Framework\\v4.0.30319\\mscorsvw.exe" in experimental wow64 mode
# 027c:fixme:thread:get_thread_times not implemented on this platform
# 027c:fixme:ntdll:NtQuerySystemInformation info_class SYSTEM_PERFORMANCE_INFORMATION
# 027c:fixme:seh:WerSetFlags (2) stub
# 027c:fixme:heap:RtlSetHeapInformation HEAP_INFORMATION_CLASS 1 not implemented!
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0130:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0154:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0164:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0160:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0164:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0158:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0024:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 0000000000413418 stub
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0160:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 014c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0134:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 013c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0168:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0130:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0158:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0148:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0144:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0138:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0024:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 0000000000413418 stub
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0024:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 013c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0140:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0144:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0160:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0114:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 014c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# ...
# 0798:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 06e8:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0730:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 01b4:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 06e8:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0190:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0610:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 05e0:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0190:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 05e0:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0798:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 01b4:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 06e8:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0720:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 06ec:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0730:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 06dc:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0720:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 06f4:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 06ec:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 06f8:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 06e8:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 018c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 01b4:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0724:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 06fc:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 070c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 06fc:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 050c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 079c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0578:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 018c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 06f8:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 06ec:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 06fc:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 06d8:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 079c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0554:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 018c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 049c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0750:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 06f4:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 06dc:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0744:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0028:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0744:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 079c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 05e0:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0240:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0028:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0718:fixme:thread:NtQueryInformationThread ThreadIsIoPending info class not supported yet
# 06b4:fixme:thread:NtQueryInformationThread ThreadIsIoPending info class not supported yet
# 0578:fixme:thread:NtQueryInformationThread ThreadIsIoPending info class not supported yet
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0240:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 06e8:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0610:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 01b4:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0028:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 070c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0260:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0270:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0700:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0750:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0610:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0494:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0724:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 018c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0610:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0724:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0798:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0750:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 02b4:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0744:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0588:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 018c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 06c0:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0610:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 06c0:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 069c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0028:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 06a0:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA0448F0) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA096CD0) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA55ECB0) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA59EA50) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA5DEA50) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA691870) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA881870) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA6EE790) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA6B4070) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA7CA390) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFAA26CD0) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA9C0530) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA8C9660) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFAC03920) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFABC67C0) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFAD0FF00) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (0000000102CCAE60) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFAFAEA50) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFAF6BE00) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFAD44EA0) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFCFE28F0) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFCF21A80) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFAFF98D0) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFB0BE7E0) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFB052600) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFBE9C8C0) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFB41F700) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFB6B1530) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFB643980) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFB725C80) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFC183580) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFC0C2640) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFC03FF60) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (0000000100E9E020) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00000000226E51C8) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (000000001B7B7810) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (000000001B647D90) stub
