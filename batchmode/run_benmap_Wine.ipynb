# %% [markdown]
# ## Run BenMAP batch mode using Wine
#
# Author : Yunha Lee
#
# Date: March 13, 2025

# %%
import os
import subprocess

# Control run names
control_runs = [ 'NEI_no_Landfill_2001411' ]# 'CO_CCS_wo_NH3_VOC', 'CO_Cherokee_CCS_wo_NH3_VOC','CO_Suncor_CCS_wo_NH3_VOC' ] # 'CO_CCS'] #, 

# Key directories
Benmap_dir = '/Users/yunhalee/Documents/LOCAETA/RCM/BenMAP/'
AQG_dir = Benmap_dir + 'batchmode/AQG/'
CFG_dir = Benmap_dir +'batchmode/CFG/'
APV_dir = Benmap_dir +'batchmode/APV/'

# wine style directories
CFGR_wine_dir = 'Z:'+ Benmap_dir + 'batchmode/CFGR/'
APVR_wine_dir = 'Z:'+ Benmap_dir + 'batchmode/APVR/'
inmap_wine_dir = 'Z:' + Benmap_dir +'inmap_output/county_case/' # directory of air quality input csv files

# Base run placeholder in template
base_run = 'base_county_inmap_2020_pm25' 

# Name of template ctlx file
ctlx_template = 'control_template_county_inmap_2020_pm25_wine.ctlx'

# Wine executable path
benmap_exe = "C:\\Program Files (x86)\\BenMAP-CE\\BenMAP.exe"

def AQG_process_template(template_path, output_path, control_run, AQG_wine_dir, inmap_wine_dir):
    """Reads a template file, replaces placeholders with actual paths, and saves the modified file."""
    with open(template_path, 'r') as f:
        content = f.read()
    
    # Replace placeholders
    content = content.replace('{AQG_wine_dir}', AQG_wine_dir)
    content = content.replace('{inmap_wine_dir}', inmap_wine_dir)
    content = content.replace('{control_run}', control_run)

    print("AQG debug", output_path)
    # Write the modified content to a new file
    with open(output_path, 'w') as f:
        f.write(content)


def CFG_process_template(template_path, output_path, control_run, base_run, CFG_wine_dir, CFGR_wine_dir, AQG_wine_dir):
    """Reads a template file, replaces placeholders with actual paths, and saves the modified file."""
    with open(template_path, 'r') as f:
        content = f.read()
    
    # Replace placeholders
    content = content.replace('{CFG_wine_dir}', CFG_wine_dir)
    content = content.replace('{CFGR_wine_dir}', CFGR_wine_dir)
    content = content.replace('{AQG_wine_dir}', AQG_wine_dir)
    content = content.replace('{control_run}', control_run)
    content = content.replace('{base_run}', base_run)

    # Write the modified content to a new file
    with open(output_path, 'w') as f:
        f.write(content)

def APV_process_template(template_path, output_path, control_run, APV_wine_dir, APVR_wine_dir, CFGR_wine_dir):
    """Reads a template file, replaces placeholders with actual paths, and saves the modified file."""
    with open(template_path, 'r') as f:
        content = f.read()
    
    # Replace placeholders
    content = content.replace('{APV_wine_dir}', APV_wine_dir)
    content = content.replace('{APVR_wine_dir}', APVR_wine_dir)
    content = content.replace('{CFGR_wine_dir}', CFGR_wine_dir)
    content = content.replace('{control_run}', control_run)

    # Write the modified content to a new file
    with open(output_path, 'w') as f:
        f.write(content)

# Function to convert Unix paths to Wine-compatible Windows paths
def convert_to_wine_path(unix_path):
    windows_path = unix_path #s.replace('/', '\\')  # Convert to Windows-style backslashes
    return "Z:" + windows_path  # Prepend Z: for Wine


for run in control_runs:

    control_run = f'control_{run}_county_inmap_2020_pm25'

    # Process and run AQG template
    AQG_wine_dir = convert_to_wine_path(AQG_dir)
    aqg_template = os.path.join(AQG_dir, ctlx_template)
    aqg_output = os.path.join(AQG_dir, f'{control_run}_wine.ctlx')
    AQG_process_template(aqg_template, aqg_output, control_run, AQG_wine_dir, inmap_wine_dir)

    subprocess.run(["wine", benmap_exe, convert_to_wine_path(aqg_output)], check=True)

    # Process and run CFG template
    CFG_wine_dir = convert_to_wine_path(CFG_dir)
    cfg_template = os.path.join(CFG_dir, ctlx_template)
    cfg_output = os.path.join(CFG_dir, f'{control_run}_wine.ctlx')
    CFG_process_template(cfg_template, cfg_output, control_run, base_run, CFG_wine_dir, CFGR_wine_dir, AQG_wine_dir)

    subprocess.run(["wine", benmap_exe, convert_to_wine_path(cfg_output)], check=True)

    # Process and run APV template
    APV_wine_dir = convert_to_wine_path(APV_dir)
    apv_template = os.path.join(APV_dir, ctlx_template)
    apv_output = os.path.join(APV_dir, f'{control_run}_wine.ctlx')
    APV_process_template(apv_template, apv_output, control_run, APV_wine_dir, APVR_wine_dir, CFGR_wine_dir)

    subprocess.run(["wine", benmap_exe, convert_to_wine_path(apv_output)], check=True)
# Out:
# AQG debug /Users/yunhalee/Documents/LOCAETA/RCM/BenMAP/batchmode/AQG/control_CO_CCS_wo_NH3_VOC_county_inmap_2020_pm25_wine.ctlx
# 0818:fixme:thread:get_thread_times not implemented on this platform
# 0818:fixme:heap:GetNumaHighestNodeNumber semi-stub: 000000000041FB74
# 0818:fixme:ntdll:NtQuerySystemInformation info_class SYSTEM_PERFORMANCE_INFORMATION
# 07fc:err:ole:CoGetContextToken apartment not initialised
# 0818:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 4 0000000000585048 0000000000419E90 000000000041A840 0000000000000000
# 0818:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 3 00000000005DBCE0 000000000041A230 000000000041ABE0 0000000000000000
# 0818:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 3 00000000005DBCE0 000000000041A230 000000000041ABE0 0000000000000000
# 0818:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 4 0000000000585048 0000000000419E90 000000000041A840 0000000000000000
# 0818:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 3 00000000005DBCE0 000000000041A230 000000000041ABE0 0000000000000000
# 0818:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 3 00000000005DBCE0 000000000041A230 000000000041ABE0 0000000000000000
# 0818:fixme:nls:get_dummy_preferred_ui_language (0x8 0x409 000000000041D0D0 0000000000000000 000000000041D0D4) returning a dummy value (current locale)
# 0818:fixme:nls:get_dummy_preferred_ui_language (0x8 0x409 000000000041D0D0 0000000000616030 000000000041D0D4) returning a dummy value (current locale)
# 0818:fixme:font:find_matching_face Untranslated charset 255
# 0818:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Apple Braille.ttf"
# 0818:fixme:font:find_matching_face Untranslated charset 255
# 0818:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\Baghdad.ttc"
# 0818:fixme:font:find_matching_face Untranslated charset 255
# 0818:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\Gujarati Sangam MN.ttc"
# 0818:fixme:font:find_matching_face Untranslated charset 255
# 0818:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\Gurmukhi Sangam MN.ttc"
# 0818:fixme:font:find_matching_face Untranslated charset 255
# 0818:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\HelveticaNeue.ttc"
# 0818:fixme:font:find_matching_face Untranslated charset 255
# 0818:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\Hoefler Text Ornaments.ttf"
# 0818:fixme:font:find_matching_face Untranslated charset 255
# 0818:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\ITFDevanagari.ttc"
# 0818:fixme:font:find_matching_face Untranslated charset 255
# 0818:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\ITFDevanagari.ttc"
# 0818:fixme:font:find_matching_face Untranslated charset 255
# 0818:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\Kailasa.ttc"
# 0818:fixme:font:find_matching_face Untranslated charset 255
# 0818:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\KohinoorGujarati.ttc"
# 0818:fixme:font:find_matching_face Untranslated charset 255
# 0818:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\KufiStandardGK.ttc"
# 0818:fixme:font:find_matching_face Untranslated charset 255
# 0818:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\Nadeem.ttc"
# 0818:fixme:font:find_matching_face Untranslated charset 255
# 0818:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\Skia.ttf"
# 0818:fixme:font:find_matching_face Untranslated charset 255
# 0818:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\ZapfDingbats.ttf"
# 0818:fixme:gdiplus:GdipGetFamilyName No support for handling of multiple languages!
# 0818:fixme:nls:LCMapStringEx unsupported lparam 5e5f00
# 0818:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0818:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 000000000041E6B8 stub
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:virtual:NtFlushProcessWriteBuffers stub
# 0818:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 000000000041E358 stub
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 0000000000418878 stub
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 00000000004188C8 stub
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 4 0000000000686208 00000000004160F0 0000000000416AA0 0000000000000000
# 0818:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 4 0000000000686208 00000000004160F0 0000000000416AA0 0000000000000000
# 0818:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 00000000004186A8 stub
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0818:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 002c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 00d8:fixme:sync:SetWaitableTimerEx (00000000000003B4, 000000001CAAFED0, 500, 0000000000000000, 0000000000000000, 0000000000000000, 50) semi-stub
# 0158:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0158:fixme:combase:RoGetActivationFactory (L"Windows.Foundation.Diagnostics.AsyncCausalityTracer", {50850b26-267e-451b-a890-ab6a370245ee}, 000000001C9AE7C0): semi-stub
# 0158:err:combase:RoGetActivationFactory Failed to find library for L"Windows.Foundation.Diagnostics.AsyncCausalityTracer"
# 07fc:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0818:fixme:msvcrt:__clean_type_info_names_internal (000000001B7B7810) stub
# 0818:fixme:msvcrt:__clean_type_info_names_internal (000000001B647D90) stub
# 01c0:fixme:thread:get_thread_times not implemented on this platform
# 01c0:fixme:heap:GetNumaHighestNodeNumber semi-stub: 000000000041FB74
# 01c0:fixme:ntdll:NtQuerySystemInformation info_class SYSTEM_PERFORMANCE_INFORMATION
# 01c8:err:ole:CoGetContextToken apartment not initialised
# 01c0:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 4 0000000000585048 0000000000419E90 000000000041A840 0000000000000000
# 01c0:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 3 00000000005DD2A0 000000000041A230 000000000041ABE0 0000000000000000
# 01c0:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 3 00000000005DD2A0 000000000041A230 000000000041ABE0 0000000000000000
# 01c0:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 4 0000000000585048 0000000000419E90 000000000041A840 0000000000000000
# 01c0:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 3 00000000005DD2A0 000000000041A230 000000000041ABE0 0000000000000000
# 01c0:fixme:combase:RoGetParameterizedTypeInstanceIID stub: 3 00000000005DD2A0 000000000041A230 000000000041ABE0 0000000000000000
# 01c0:fixme:nls:get_dummy_preferred_ui_language (0x8 0x409 000000000041D0D0 0000000000000000 000000000041D0D4) returning a dummy value (current locale)
# 01c0:fixme:nls:get_dummy_preferred_ui_language (0x8 0x409 000000000041D0D0 000000000061ACE0 000000000041D0D4) returning a dummy value (current locale)
# 01c0:fixme:font:find_matching_face Untranslated charset 255
# 01c0:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Apple Braille.ttf"
# 01c0:fixme:font:find_matching_face Untranslated charset 255
# 01c0:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\Baghdad.ttc"
# 01c0:fixme:font:find_matching_face Untranslated charset 255
# 01c0:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\Gujarati Sangam MN.ttc"
# 01c0:fixme:font:find_matching_face Untranslated charset 255
# 01c0:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\Gurmukhi Sangam MN.ttc"
# 01c0:fixme:font:find_matching_face Untranslated charset 255
# 01c0:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\HelveticaNeue.ttc"
# 01c0:fixme:font:find_matching_face Untranslated charset 255
# 01c0:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\Hoefler Text Ornaments.ttf"
# 01c0:fixme:font:find_matching_face Untranslated charset 255
# 01c0:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\ITFDevanagari.ttc"
# 01c0:fixme:font:find_matching_face Untranslated charset 255
# 01c0:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\ITFDevanagari.ttc"
# 01c0:fixme:font:find_matching_face Untranslated charset 255
# 01c0:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\Kailasa.ttc"
# 01c0:fixme:font:find_matching_face Untranslated charset 255
# 01c0:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\KohinoorGujarati.ttc"
# 01c0:fixme:font:find_matching_face Untranslated charset 255
# 01c0:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\KufiStandardGK.ttc"
# 01c0:fixme:font:find_matching_face Untranslated charset 255
# 01c0:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\Nadeem.ttc"
# 01c0:fixme:font:find_matching_face Untranslated charset 255
# 01c0:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\Supplemental\\Skia.ttf"
# 01c0:fixme:font:find_matching_face Untranslated charset 255
# 01c0:fixme:font:get_nearest_charset returning DEFAULT_CHARSET face->fs.fsCsb[0] = 00000000 file = L"\\??\\Z:\\System\\Library\\Fonts\\ZapfDingbats.ttf"
# 01c0:fixme:gdiplus:GdipGetFamilyName No support for handling of multiple languages!
# 01c0:fixme:nls:LCMapStringEx unsupported lparam 5fb490
# 01c0:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 01c0:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 000000000041E6B8 stub
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:virtual:NtFlushProcessWriteBuffers stub
# 01c0:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 000000000041E358 stub
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 0000000000418258 stub
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 00000000004184B8 stub
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 0000000000418558 stub
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 01c0:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# ...
# 0804:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0050:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0804:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 037c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 02d8:err:listview:LISTVIEW_WindowProc unknown msg 109d, wp 0, lp 0
# 02d8:err:listview:LISTVIEW_SetImageList Unknown icon type=3
# 02d8:err:listview:LISTVIEW_WindowProc unknown msg 109b, wp 0, lp 40f150
# 02d8:err:listview:LISTVIEW_WindowProc unknown msg 109d, wp 0, lp 0
# 02d8:err:listview:LISTVIEW_SetImageList Unknown icon type=3
# 02d8:err:listview:LISTVIEW_WindowProc unknown msg 109b, wp 0, lp 40f150
# 02d8:err:listview:LISTVIEW_WindowProc unknown msg 109d, wp 0, lp 0
# 02d8:err:listview:LISTVIEW_SetImageList Unknown icon type=3
# 02d8:err:listview:LISTVIEW_WindowProc unknown msg 109b, wp 0, lp 40f150
# 02d8:err:listview:LISTVIEW_WindowProc unknown msg 109d, wp 0, lp 0
# 02d8:err:listview:LISTVIEW_SetImageList Unknown icon type=3
# 02d8:err:listview:LISTVIEW_WindowProc unknown msg 109b, wp 0, lp 40f150
# 02d8:err:listview:LISTVIEW_WindowProc unknown msg 109d, wp 0, lp 0
# 02d8:err:listview:LISTVIEW_SetImageList Unknown icon type=3
# 02d8:err:listview:LISTVIEW_WindowProc unknown msg 109b, wp 0, lp 40f150
# 0804:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0378:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 02d8:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 00000000004180D8 stub
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 0000000000417F38 stub
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 0000000000417CC8 stub
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 0000000000417D68 stub
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0804:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 037c:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 02d8:fixme:ole:CoGetDefaultContext -1, {000001c6-0000-0000-c000-000000000046}, 00000000004188F8 stub
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 02d8:fixme:ole:thread_context_info_QueryInterface interface not implemented {51372ae0-cae7-11cf-be81-00aa00a2fa25}
# 0804:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0344:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0804:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0384:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0804:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0358:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0804:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0370:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0804:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0384:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0804:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0274:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0804:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0340:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0804:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0388:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0804:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0378:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0804:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 02c8:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0804:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0818:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0804:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0364:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0804:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0358:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0804:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 0274:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 07f4:fixme:thread:NtGetCurrentProcessorNumber need multicore support (16 processors)
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA0448F0) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA096CD0) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA55ECB0) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA59EA50) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA5DEA50) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA691870) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA881870) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA6EE790) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA6B4070) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA7CA390) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFAA26CD0) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA9C0530) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFA8C9660) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFAC03920) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFABC67C0) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFAD0FF00) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (0000000102DCAE60) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFAFAEA50) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFAF6BE00) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFAD44EA0) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFCFE28F0) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFCF21A80) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFAFF98D0) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFB0BE7E0) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFB052600) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFBE9C8C0) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFB41F700) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFB6B1530) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFB643980) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFB725C80) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFC183580) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFC0C2640) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00006FFFFC03FF60) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (00000001008AE020) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (0000000022E051C8) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (000000001B7B7810) stub
# 02d8:fixme:msvcrt:__clean_type_info_names_internal (000000001B647D90) stub

# %%
AQG_wine_dir
# Out:
# 'Z:/Users/yunhalee/Documents/LOCAETA/RCM/BenMAP/batchmode/AQG/'
